# %%
import csv
import pandas as pd
import ScraperFC as sfc
fb = sfc.FBref()

# %%
match_df = fb.scrape_matches("2022-2023", "Bundesliga")
match_df.head()
# Out:
# 2022-2023 Bundesliga matches: 100%|██████████| 306/306 [29:19<00:00,  5.75s/it]
#                                                 Link       Date        Stage  \
# 0  https://fbref.com/en/matches/6a1c18c4/Eintrach... 2022-08-05  Matchweek 1
# 1  https://fbref.com/en/matches/3c5c48d7/Augsburg... 2022-08-06  Matchweek 1
# 2  https://fbref.com/en/matches/1591be13/Wolfsbur... 2022-08-06  Matchweek 1
# 3  https://fbref.com/en/matches/58e704e1/Union-Be... 2022-08-06  Matchweek 1
# 4  https://fbref.com/en/matches/b9e40750/Bochum-M... 2022-08-06  Matchweek 1
#
#              Home Team      Away Team Home Team ID Away Team ID  \
# 0  Eintracht Frankfurt  Bayern Munich     f0ac8ee6     054efa67
# 1             Augsburg       Freiburg     0cdc4311     a486e511
# 2            Wolfsburg  Werder Bremen     4eaa11d7     62add3bf
# 3         Union Berlin     Hertha BSC     7a41008f     2818f8bc
# 4               Bochum       Mainz 05     b42c6323     a224b06a
#
#   Home Formation Away Formation Home Goals  ... Away Ast Home xG Away xG  \
# 0          3-4-3          4-4-2          1  ...        4     0.9     4.0
# 1        3-1-4-2        4-2-3-1          0  ...        2     0.7     1.2
# 2        4-2-3-1          3-5-2          2  ...        2     1.0     0.8
# 3          3-5-2          4-3-3          3  ...        1     1.0     0.3
# 4        4-2-3-1          5-4-1          1  ...        2     0.9     1.4
#
#   Home npxG Away npxG Home xAG Away xAG  \
# 0       0.9       4.0      0.3      3.3
# 1       0.7       1.2      0.6      0.7
# 2       1.0       0.8      0.8      0.6
# 3       1.0       0.3      1.0      0.2
# 4       0.9       1.4      0.6      1.1
#
#                                    Home Player Stats  \
# 0                                            Team...
# 1                                            Team...
# 2                                            Team...
# 3                                            Team...
# 4                                            Team...
#
#                                    Away Player Stats  \
# 0                                            Team...
# 1                                            Team...
# 2                                            Team...
# 3                                            Team...
# 4                                            Team...
#
#                                                Shots
# 0                                                ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...
#
# [5 rows x 22 columns]

# %%
# create 2022 season csv

match_df.to_csv('bundesliga_2022.csv')

# %%
# scrape 2021 season csv

match_df = fb.scrape_matches("2021-2022", "Bundesliga")
match_df.head()

match_df.to_csv('bundesliga_2021.csv')
# Out:
# 2021-2022 Bundesliga matches: 100%|██████████| 306/306 [28:03<00:00,  5.50s/it]

# %%
# scrape 2021 season csv

match_df = fb.scrape_matches("2023-2024", "Bundesliga")
match_df.head()

match_df.to_csv('bundesliga_2023.csv')
# Out:
# 2023-2024 Bundesliga matches: 100%|██████████| 306/306 [29:04<00:00,  5.70s/it]
